# %% [markdown]
# # function
# 1 fgrfgdsfsjdgss
# - dsfddaadsfgh

# %% [markdown]
# 1 my question is
# - this is answer

# %%
# question
...

...
"""
this is answer

"""
# Out:
# '\nthis is answer\n\n'
